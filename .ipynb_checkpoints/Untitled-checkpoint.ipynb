# %%
# %matplotlib inline
import matplotlib.puplot as plt
import numpu as np
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-568e3b1915aa> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 import matplotlib.puplot as plt
#       3 import numpu as np
#       4 x = np.linspace(0, 3*np.pi, 500)
#       5 plt.plot(x, np.sin(x**2))
#
# ModuleNotFoundError: No module named 'matplotlib.puplot'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpu as np
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-fee3625f4003> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
# ----> 3 import numpu as np
#       4 x = np.linspace(0, 3*np.pi, 500)
#       5 plt.plot(x, np.sin(x**2))
#
# ModuleNotFoundError: No module named 'numpu'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))

# %% [markdown]
# $$F(k) = \int_{\infty}^{\infty} f(x) e^{2\pi i k} dx$$
